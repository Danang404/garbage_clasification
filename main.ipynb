# %%
from src.config import RAW_DATA_DIR
from src.split_data import split_data_physically
from src.eda import run_eda
from src.data_loader import get_dataloaders

# %%
def main():
   

    # 1. EDA
    print("\n!!! Running : Exploratory Data Analysis !!!")
    run_eda(RAW_DATA_DIR)

     # 2. Split Data
    split_data_physically()

 # 3. Preprocessing dan load data
    print("\n!!! Running : Data Loaders !!!")
    train_ds, val_ds, test_ds = get_dataloaders()

# %%
main()
# Out:
# !!! Running : Exploratory Data Analysis !!!
#
# TAHAP 1: EXPLORATORY DATA ANALYSIS (EDA)
# d:\mendeley\pdm\garbage_clasification\src\eda.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()), palette='viridis')
# Total kelas: 12
# Rincian data per kelas: {'battery': 945, 'biological': 985, 'brown-glass': 607, 'cardboard': 891, 'clothes': 5325, 'green-glass': 629, 'metal': 769, 'paper': 1050, 'plastic': 865, 'shoes': 1977, 'trash': 697, 'white-glass': 775}
# TAHAP 2: PEMISAHAN DATA FISIK (SPLITTING)
# Data sudah pernah dipisah. Melewati tahap ini agar lebih cepat.
#
# !!! Running : Data Loaders !!!
#
# TAHAP 3: MEMUAT DATALOADER
# Found 10854 files belonging to 12 classes.
# Found 2321 files belonging to 12 classes.
# Found 2340 files belonging to 12 classes.
# Total Data Train: 10854 gambar (340 batch)
# Total Data Validasi: 2321 gambar (73 batch)
# Total Data Test: 2340 gambar (74 batch)
# Dataloader siap!
# Batch Training: 340
# Batch Validasi: 73
# Batch Test: 74
